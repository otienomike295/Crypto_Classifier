# %%
# ==========================================
# 1. SETUP & IMPORTS
# ==========================================
import sys
import os
import importlib

# Add 'src' to the path so we can import our scripts
# We use abspath to ensure it works regardless of where the notebook is running
sys.path.append(os.path.abspath('../src'))

# Import the training script
import train

# Force reload (Crucial if you edited train.py while the notebook was open)
importlib.reload(train)

# ==========================================
# 2. EXECUTE TRAINING FACTORY
# ==========================================
print("STARTING MODEL FACTORY...")
print("   - This will train LogisticRegression, RF, XGBoost, LightGBM, and CatBoost.")
print("   - All models will be saved to the 'models/' folder.")
print("   - No evaluation happens here (that's for the next notebook).\n")

# Run the function
train.train_models()
# Out:
# STARTING MODEL FACTORY...
#    - This will train LogisticRegression, RF, XGBoost, LightGBM, and CatBoost.
#    - All models will be saved to the 'models/' folder.
#    - No evaluation happens here (that's for the next notebook).
#
#  Starting Factory Training (Saving ALL models)...
#    Training Data: 560 rows (First 70%)
#    Features: 17
#
#     Training 5 models...
#       - Training LogisticRegression...  Saved to models/LogisticRegression.pkl
#       - Training RandomForest...  Saved to models/RandomForest.pkl
#       - Training XGBoost...  Saved to models/XGBoost.pkl
#       - Training LightGBM...  Saved to models/LightGBM.pkl
#       - Training CatBoost...  Saved to models/CatBoost.pkl
#
#  All models trained and saved to c:\Users\motieno\Downloads\Data Science\python\Statitistics\Capstone\Crypto_Classifier\models
